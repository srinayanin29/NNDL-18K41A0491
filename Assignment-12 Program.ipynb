# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split
import seaborn as sns
from scipy import stats

# %% [markdown]
# **Read** **data**

# %%
data=pd.read_excel("Load_Data_in_kW.xlsx",header=None)
data.head()
# Out:
#             0
# 0  5551.82208
# 1  4983.17184
# 2  4888.39680
# 3  5072.95872
# 4  5196.25980

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2184 entries, 0 to 2183
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2184 non-null   float64
# dtypes: float64(1)
# memory usage: 17.2 KB

# %% [markdown]
# **Outliers**

# %%
z=np.abs(stats.zscore(data))
print(z)
# Out:
# [[0.04910416]
#  [0.08229029]
#  [0.08782131]
#  ...
#  [0.09743692]
#  [0.07253822]
#  [0.03181432]]

# %%
sns.boxplot(x=data[0])

# %%
df=data
q=df[0].quantile(0.99)
df[df[0]<q]
q_low=df[0].quantile(0.01)
q_hi=df[0].quantile(0.99)
df_filtered=df[(df[0]<q_hi)&(df[0]>q_low)]
df_filtered.head()
# Out:
#             0
# 0  5551.82208
# 1  4983.17184
# 2  4888.39680
# 3  5072.95872
# 4  5196.25980

# %%
print(len(data))
print(len(df_filtered))
if(len(data)==len(df_filtered)):
  print('No outliers')
# Out:
# 2184
# 2140

# %% [markdown]
# **Normalisation:**

# %%
data=df_filtered
data_n=data.copy()
data_n=(data_n-data_n.min())/(data_n.max()-data_n.min())
data_n.head()
# Out:
#           0
# 0  0.372950
# 1  0.254941
# 2  0.235273
# 3  0.273574
# 4  0.299162

# %% [markdown]
# **Split Data:**

# %%
train_data,test_data = train_test_split(data_n,test_size=0.1)
print(len(train_data))
train_data.head()
# Out:
# 1926
#              0
# 1058  0.456507
# 2106  0.444894
# 1427  0.807718
# 1784  0.782777
# 1699  0.213535

# %%
x=[]
y=[]
for i in range(len(train_data.iloc[:,0])-24):
  x.append(train_data.iloc[i,0])
  y.append(train_data.iloc[i+24,0])

# %% [markdown]
# **Train Data**

# %%
m=1
c=-1
epochs=25  # epochs
l=0.1      # learning rate
ns=len(x)
gama=0.9
vm=0
vc=0
err=[]
for i in range(epochs):
  er=0
  for j in range(len(x)):
    er+=((y[j]-(m*x[j])-c))**2
    gm=((-1)*(y[j]-(m+(gama*vm))*x[j]-(c+(gama*vc)))*(x[j]))
    gc=((-1)*(y[j]-(m+(gama*vm))*x[j]-(c+(gama*vc))))
    vm=(gama*vm)-(l*gm)
    vc=(gama*vc)-(l*gc)
    m=m+vm
    c=c+vc
    er=(1/(2*len(x)))*(er)
    err.append(er)
print("The local minimum occurs at m = %.2f"%(m),", c = %.2f"%(c))
# Out:
# The local minimum occurs at m = 0.01 , c = 0.48

# %% [markdown]
# **RMSE for Training data**

# %%
yp=[]
for i in range(len(x)):
  p=m*x[i]+c
  yp.append(p)
sum=0
for i in range(len(x)):
  sum+=(y[i]-yp[i])**2
  mse=sum/len(x)
print("Mean Square Error (MSE) : ",mse)
# Out:
# Mean Square Error (MSE) :  0.04520300208255339

# %%
plt.plot(np.array(x),np.array(yp),'green')
plt.scatter(np.array(x),np.array(y),color='red')
plt.title("Predicted data vs Actual data")
# Out:
# Text(0.5, 1.0, 'Predicted data vs Actual data')

# %%
iters=np.arange(epochs*len(x))
plt.plot(iters,err,'green')
plt.title("Error graph for training data")
plt.xlabel("iteration count")
plt.ylabel("error")
plt.grid()

# %% [markdown]
# **Test Data:**

# %%
tx=[]
ty=[]
for i in range(len(test_data.iloc[:,0])-24):
    tx.append(test_data.iloc[i,0])
    ty.append(test_data.iloc[i+24,0])

yp1=[]
for i in range(len(tx)):
  p1=m*tx[i]+c
  yp1.append(p1)
sum=0
for i in range(len(tx)):
  sum+=(ty[i]-yp1[i])**2
  mse1=sum/len(tx)
print("Mean Square Error (MSE) : ",mse1)
# Out:
# Mean Square Error (MSE) :  0.03827270864806019

# %%
plt.scatter(tx,ty,color='red')
plt.plot(tx,yp1,'green')
plt.grid()

# %% [markdown]
# **Predict Output:**

# %%
x_max=y_max= 8841.669480
x_min=y_min= 3377.919600
x2=float(input("Enter load of previous hour : "))
xi=(x2-x_min)/(x_max-x_min)
yi=m*xi+c
yi=yi*(y_max-y_min)+y_min
print("Load at hour based on its previous hour {} is : {}".format(x2,yi))
# Out:
# Enter load of previous hour : 5551.822
# Load at hour based on its previous hour 5551.822 is : 6042.934974941383
